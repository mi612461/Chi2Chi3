# %%
using QuantumOptics
using DifferentialEquations
using SpecialFunctions
using CairoMakie 
using GLMakie
using LsqFit
using Statistics
using DataFrames
using CSV
using JSON
using PhysicalConstants
IJulia
# Out:
# IJulia

# %%
println("Hello Worled")
# Out:
# Hello Worled

# %%
N = 50;      #Number of Photons  
basis = FockBasis(N); 
at = create(basis);
a = destroy(basis);

#These are just constants now. I will fill them with more realistic values later!!!
chi2 = 0.5;  #Second Order Nonlinearity 
kerr = 0.025; #Kerr effect 
pump_amplitude = 2; 

H_free = pump_amplitude ()
H_int =
# Out:
# ParseError:
# # Error @ ]8;;file://C:/Users/mi612461/Desktop/In[8]#11:9\In[8]:11:9]8;;\
# H_free =
# H_int =
# #       └ ── premature end of input
#
# Stacktrace:
#  [1] top-level scope
#    @ In[8]:11
#  [2] eval(m::Module, e::Any)
#    @ Core .\boot.jl:489
